# %%
import pickle
import numpy as np

# %%
ohe_s = pickle.load(open('models/ohe_s.pkl','rb'))
ohe_e = pickle.load(open('models/ohe_e.pkl','rb'))
dc = pickle.load(open('models/dc.pkl','rb'))

# %%
test_i = np.array([2,'male',56.0,1,0,10,'S'],dtype=object).reshape(1,7)

# %%
testis = ohe_s.transform(test_i[:,1].reshape(1,1))
# Out:
# z:\machineln\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
testis
# Out:
# array([[0., 1.]])

# %%
testie = ohe_e.transform(test_i[:,-1].reshape(1,1))

# %%
testie
# Out:
# array([[0., 0., 1.]])

# %%
testia = test_i[:,2].reshape(1,1)

# %%
testia
# Out:
# array([[56.0]], dtype=object)

# %%
test_i_t = np.concatenate((test_i[:,[0,3,4,5]],testis,testia,testie),axis=1)

# %%
test_i_t.shape
# Out:
# (1, 10)

# %%
dc.predict(test_i_t)
# Out:
# array([0])

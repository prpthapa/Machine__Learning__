# %% [markdown]
# # Tensor

# %%
import numpy as np

# %% [markdown]
# # 0D Tensor/Scalar

# %%
a = np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %% [markdown]
# # 1D Tensor/vector

# %%
b = np.arange(6)

# %%
b
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
b.ndim
# Out:
# 1

# %% [markdown]
# # 2D Tensor/Matrices

# %%
c = np.arange(6).reshape(2,3)

# %%
c
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
c.ndim
# Out:
# 2

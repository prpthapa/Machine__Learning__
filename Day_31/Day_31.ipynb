# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##  Load train.csv and display its shape, column names, and the first 10 rows. How many passengers are in the training set?

# %%
df = pd.read_csv('titanic/train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# df.head(10)

# %%
df.shape[0]
# Out:
# 891

# %% [markdown]
# ## Check for missing values in train.csv. Which columns have nulls? What percentage of values are missing in the Age and Cabin columns?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# ## Q3. Using pandas, find the data types of all columns. Which columns should ideally be categorical? Convert Survived, Pclass, and Sex to category dtype.

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived       category
# Pclass            int64
# Name                str
# Sex                 str
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket              str
# Fare            float64
# Cabin               str
# Embarked            str
# dtype: object

# %%
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')
df['Sex'] = df['Sex'].astype('category')

# %%
df.dtypes
# Out:
# PassengerId       int64
# Survived       category
# Pclass         category
# Name                str
# Sex            category
# Age             float64
# SibSp             int64
# Parch             int64
# Ticket              str
# Fare            float64
# Cabin               str
# Embarked            str
# dtype: object

# %% [markdown]
# ## Compute descriptive statistics (mean, median, std, min, max) for Age, Fare, and SibSp using .describe(). What is the average fare paid?

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['SibSp'].describe()
# Out:
# count    891.000000
# mean       0.523008
# std        1.102743
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        8.000000
# Name: SibSp, dtype: float64

# %%
print(df['Fare'].mean())
# Out:
# 32.204207968574636

# %% [markdown]
# # Dataframe
#
# #### It's a structured data constructed with rows and columns, similar to a SQL tables or Excel tables

# %%
import pandas as pd

# %%
# Create Dataframe
df = pd.DataFrame([11,22,33],columns=['col_name'])
print(df)
# Out:
#    col_name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'name':['Ram','Shyam','Hari'],
    'age':[16,17,18],
    'salary':[40000,50000,60000]
           
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     name  age  salary
# 0    Ram   16   40000
# 1  Shyam   17   50000
# 2   Hari   18   60000

# %% [markdown]
# ## Basic DataFrame

# %%
df.head(2)
# Out:
#     name  age  salary
# 0    Ram   16   40000
# 1  Shyam   17   50000

# %%
df.tail(2)
# Out:
#     name  age  salary
# 1  Shyam   17   50000
# 2   Hari   18   60000

# %%
df.shape
# Out:
# (3, 3)

# %%
df.columns
# Out:
# Index(['name', 'age', 'salary'], dtype='str')

# %%
df.rename(columns={'salary' : 'fortnight_Salary'},inplace='True')

# %%
df
# Out:
#     name  age  fortnight_Salary
# 0    Ram   16             40000
# 1  Shyam   17             50000
# 2   Hari   18             60000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              3 non-null      str
#  1   age               3 non-null      int64
#  2   fortnight_Salary  3 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 204.0 bytes

# %%
df.describe()
# Out:
#         age  fortnight_Salary
# count   3.0               3.0
# mean   17.0           50000.0
# std     1.0           10000.0
# min    16.0           40000.0
# 25%    16.5           45000.0
# 50%    17.0           50000.0
# 75%    17.5           55000.0
# max    18.0           60000.0

# %%
# saving and loading the file
df.to_csv('Z:/test.csv',index=False)

# %%
load_df = pd.read_csv('Z:/test.csv')
load_df
# Out:
#     name  age  fortnight_Salary
# 0    Ram   16             40000
# 1  Shyam   17             50000
# 2   Hari   18             60000

# %% [markdown]
# ## Rows & columns - Selection

# %%
# column selection
df[['name']]
# Out:
#     name
# 0    Ram
# 1  Shyam
# 2   Hari

# %%
df[['name','fortnight_Salary']]
# Out:
#     name  fortnight_Salary
# 0    Ram             40000
# 1  Shyam             50000
# 2   Hari             60000

# %%
# select the rows -> label based 

df.loc[df.name=='Ram']
# Out:
#   name  age  fortnight_Salary
# 0  Ram   16             40000

# %%
# select the rows - index value based

df.iloc[0]
# Out:
# name                  Ram
# age                    16
# fortnight_Salary    40000
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#     name  age  fortnight_Salary
# 0    Ram   16             40000
# 1  Shyam   17             50000

# %%
# filter dataframe

age_fil = df[df['age'] > 17]
age_fil
# Out:
#    name  age  fortnight_Salary
# 2  Hari   18             60000

# %%
df[(df['age'] > 17) & (df['fortnight_Salary' ] > 20000)]
# Out:
#    name  age  fortnight_Salary
# 2  Hari   18             60000

# %%
df.where(df['age'] > 17)
# Out:
#    name   age  fortnight_Salary
# 0   NaN   NaN               NaN
# 1   NaN   NaN               NaN
# 2  Hari  18.0           60000.0

# %%
df.where(df['age'] > 17,other = 'not eligible')
# Out:
#            name           age fortnight_Salary
# 0  not eligible  not eligible     not eligible
# 1  not eligible  not eligible     not eligible
# 2          Hari            18            60000

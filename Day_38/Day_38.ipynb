# %%
import pandas as pd

# %% [markdown]
# # JSON TO PANDAS DATAFRAME

# %%
js = pd.read_json('train.json')

# %%
js
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# # SQL TO PANDAS DATAFRAME

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#       --------------------------------------- 0.3/11.9 MB ? eta -:--:--
#      - ------------------------------------- 0.5/11.9 MB 932.9 kB/s eta 0:00:13
#      --- ------------------------------------ 1.0/11.9 MB 1.5 MB/s eta 0:00:08
#      ------ --------------------------------- 1.8/11.9 MB 2.2 MB/s eta 0:00:05
#      ------ --------------------------------- 1.8/11.9 MB 2.2 MB/s eta 0:00:05
#      --------------- ------------------------ 4.5/11.9 MB 3.6 MB/s eta 0:00:03
#      ----------------- ---------------------- 5.2/11.9 MB 3.7 MB/s eta 0:00:02
# ...

# %%
import mysql.connector

# %%
tion = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode LIKE 'NEP'",tion)
# Out:
# C:\Users\prpth\AppData\Local\Temp\ipykernel_1204\176874055.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY WHERE CountryCode LIKE 'NEP'",tion)
# Empty DataFrame
# Columns: [ID, Name, CountryCode, District, Population]
# Index: []

# %%
pd.read_sql_query("SELECT * FROM CITY",tion)
# Out:
# C:\Users\prpth\AppData\Local\Temp\ipykernel_1204\666694532.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM CITY",tion)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...

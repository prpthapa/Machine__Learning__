# %%
import pandas as pd

# %% [markdown]
# # Data Accesssing
#
# ## Types of unclean data
# ### - Dirty data(Data with quality issues)
#
# - Duplicated data
# - Missing data
# - Corrupt data
# - inaccurate data

# %% [markdown]
# ### - Messy Data(data with tideness issues)
#
# ## Tidy data has following properties:
#
# - Each variable forms a column
# - Each observation forms a row
# - Each observation unit forms a table

# %%
import numpy as np
import pandas as pd

# %%
daf = pd.read_csv('placement.csv')

# %%
daf.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
daf = daf.iloc[:,1:]

# %%
daf.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(daf['cgpa'],daf['iq'],c=daf['placement'])

# %%
x = daf.iloc[:,0:2]
y = daf.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 65   8.1  166.0
# 51   4.8  141.0
# 36   5.7  140.0
# 30   7.6  128.0
# 17   3.3  183.0
# ..   ...    ...
# 70   6.3  127.0
# 19   5.2  132.0
# 76   4.9  155.0
# 62   6.0  102.0
# 58   8.0   79.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 41   5.4  114.0
# 83   7.5  130.0
# 86   5.1  128.0
# 55   7.8  114.0
# 8    6.1  156.0
# 29   7.0  112.0
# 77   7.3   50.0
# 96   4.4   42.0
# 13   6.4  116.0
# 87   5.7  132.0

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.87549406,  1.02072904],
#        [-1.01662295,  0.3959629 ],
#        [-0.22786376,  0.37097225],
#        [ 1.43729452,  0.0710845 ],
#        [-2.33122159,  1.44557002],
#        [ 1.17437479, -0.22880324],
#        [-0.84134313, -0.85356939],
#        [ 0.73617524, -0.05386873],
#        [ 0.82381515, -0.72861616],
#        [ 0.03505596,  0.59588806],
#        [-1.36718259,  0.59588806],
#        [-0.22786376,  1.09570098],
#        [-1.10426286, -0.10385002],
#        [ 0.29797569,  0.0710845 ],
#        [-0.49078349,  0.34598161],
#        [-0.92898304,  0.22102838],
#        [-0.66606331, -0.87856003],
#        [ 0.03505596, -2.00313909],
#        [ 0.56089542,  0.32099096],
#        [-0.05258395, -0.4787097 ],
#        [-1.01662295,  1.09570098],
#        [-0.84134313, -0.17882195],
#        [-0.22786376,  0.44594419],
#        [ 0.03505596, -0.02887808],
#        [ 1.43729452, -0.90355068],
#        [ 0.91145506,  0.34598161],
#        [ 1.17437479,  0.29600031],
#        [ 1.34965461, -1.60328876],
#        [-0.14022386,  1.02072904],
#        [ 0.73617524, -0.87856003],
#        [ 0.03505596, -1.47833553],
#        [-0.75370322, -1.47833553],
#        [-0.49078349, -0.45371906],
#        [-1.4548225 ,  1.87041099],
#        [-0.5784234 , -0.27878454],
#        [-1.80538214, -0.40373776],
#        [ 0.99909497,  0.64586935],
#        [ 0.21033578, -0.30377518],
#        [ 2.05077388,  1.07071033],
#        [-2.15594177,  2.6951023 ],
#        [ 2.2260537 , -0.12884066],
#        [-0.5784234 , -0.10385002],
#        [ 0.29797569, -0.55368164],
#        [ 0.56089542, -0.12884066],
#        [ 0.12269587, -1.10347584],
#        [-0.92898304,  0.64586935],
#        [-1.01662295, -0.32876583],
#        [ 0.64853533,  1.42057937],
#        [-1.10426286, -0.95353197],
#        [ 0.12269587,  0.17104709],
#        [ 1.87549406,  0.59588806],
#        [ 0.12269587, -1.50332617],
#        [-0.84134313, -1.55330747],
#        [-0.14022386,  0.42095354],
#        [-0.66606331, -0.37874712],
#        [-0.75370322,  1.2706355 ],
#        [ 0.73617524, -0.32876583],
#        [ 0.82381515,  0.32099096],
#        [ 0.12269587, -0.55368164],
#        [-0.92898304,  1.77044841],
#        [ 0.73617524,  0.3959629 ],
#        [ 0.3856156 ,  0.3959629 ],
#        [-0.92898304, -1.60328876],
#        [-1.19190277,  0.52091613],
#        [ 0.91145506, -1.52831682],
#        [ 0.99909497, -1.92816715],
#        [-1.71774223, -1.25341972],
#        [-0.66606331,  0.89577581],
#        [-1.10426286, -1.82820457],
#        [ 0.47325551,  0.87078517],
#        [-1.71774223, -0.62865358],
#        [ 1.34965461,  0.82080387],
#        [ 0.91145506,  1.24564485],
#        [-1.01662295,  0.9457571 ],
#        [ 0.47325551, -2.20306425],
#        [ 1.2620147 ,  0.17104709],
#        [ 0.91145506,  1.84542035],
#        [-0.92898304, -0.12884066],
#        [-0.49078349,  0.24601902],
#        [ 0.47325551, -0.87856003],
#        [ 0.47325551,  0.12106579],
#        [ 0.82381515,  0.34598161],
#        [ 1.17437479, -0.97852262],
#        [-0.66606331,  2.47018649],
#        [ 0.64853533,  0.72084129],
#        [ 0.29797569,  0.04609386],
#        [-0.66606331,  0.17104709],
#        [-0.92898304,  0.74583194],
#        [ 0.03505596, -0.57867228],
#        [ 1.78785415, -1.15345714]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)
# Out:
# Z:\machineln\Lib\site-packages\sklearn\utils\validation.py:2684: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
y_test
# Out:
# 41    0
# 83    1
# 86    0
# 55    1
# 8     0
# 29    1
# 77    1
# 96    0
# 13    1
# 87    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
